# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
pip install pandas numpy seaborn matplotlib jupyter

# %%
data = sns.load_dataset("penguins").dropna().values
df = pd.DataFrame(data, columns=["especie", "isla", "longitud_pico (mm)", "profundidad_pico (mm)", "longitud_aleta (mm)", "masa_corporal (g)", "genero"])

df[:5]
# Out:
#   especie       isla longitud_pico (mm) profundidad_pico (mm)  \
# 0  Adelie  Torgersen               39.1                  18.7
# 1  Adelie  Torgersen               39.5                  17.4
# 2  Adelie  Torgersen               40.3                  18.0
# 3  Adelie  Torgersen               36.7                  19.3
# 4  Adelie  Torgersen               39.3                  20.6
#
#   longitud_aleta (mm) masa_corporal (g)  genero
# 0               181.0            3750.0    Male
# 1               186.0            3800.0  Female
# 2               195.0            3250.0  Female
# 3               193.0            3450.0  Female
# 4               190.0            3650.0    Male

# %%
torgersen = df[df["isla"] == "Torgersen"]
max_prof = torgersen["profundidad_pico (mm)"].max()
min_prof = torgersen["profundidad_pico (mm)"].min()

print("maximo",max_prof,"minimo", min_prof)
# Out:
# maximo 21.5 minimo 15.9

# %%
idx = df["masa_corporal (g)"].idxmax()

resultado = df.loc[idx, ["isla", "especie", "genero"]]

print(resultado)
# Out:
# isla       Biscoe
# especie    Gentoo
# genero       Male
# Name: 231, dtype: str

# %%
filtro = df[
    (df["genero"] == "Male") &
    (df["especie"] != "Gentoo")
]

media = filtro["masa_corporal (g)"].astype(float).mean()

print("Promedio:", media)
# Out:
# Promedio: 4010.2803738317757

# %%
import matplotlib.pyplot as plt

pico = df["longitud_pico (mm)"].astype(float)

media = pico.mean()
std = pico.std()

plt.hist(pico)

plt.title(f"Distribución longitud del pico\nMedia={media:.2f}, Std={std:.2f}")
plt.xlabel("Longitud pico (mm)")
plt.ylabel("Frecuencia")

plt.show()

# %%
print("Islas presentes:")
print(df["isla"].unique())

print("\nFrecuencia de islas:")
print(df["isla"].value_counts())

print("\nEspecies presentes:")
print(df["especie"].unique())

print("\nFrecuencia de especies:")
print(df["especie"].value_counts())

import matplotlib.pyplot as plt

masa = df["masa_corporal (g)"].astype(float)

plt.hist(masa)
plt.xlabel("Masa corporal (g)")
plt.ylabel("Frecuencia")
plt.title("Distribución de la masa corporal de los pingüinos")

plt.show()
# Out:
# Islas presentes:
# <StringArray>
# ['Torgersen', 'Biscoe', 'Dream']
# Length: 3, dtype: str
#
# Frecuencia de islas:
# isla
# Biscoe       163
# Dream        123
# Torgersen     47
# Name: count, dtype: int64
#
# Especies presentes:
# <StringArray>
# ['Adelie', 'Chinstrap', 'Gentoo']
# Length: 3, dtype: str
#
# Frecuencia de especies:
# especie
# Adelie       146
# Gentoo       119
# Chinstrap     68
# Name: count, dtype: int64
